# %% [markdown]
# # CFDE C2M2 Model Mapping

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from bento_meta.mdb.mdb_tools import ToolsMDB

# %% [markdown]
# ### DSS Mapping

# %% [markdown]
# ##### Import clean DSS mappings

# %%
dss_mapping_df = pd.read_csv("Mappings/CRDC DST Cross-Model Mapping_clean.csv")

# %%
dss_mapping_df.shape
# Out:
# (303, 6)

# %%
dss_mapping_df.head()
# Out:
#   ent_1_model ent_1_handle ent_1_extra_handles ent_2_model ent_2_handle  \
# 0         DST   Identifier         ['Subject']        CTDC      case_id
# 1         DST   Identifier         ['Subject']         GDC           id
# 2         DST   Identifier         ['Subject']        ICDC      case_id
# 3         DST   Identifier         ['Subject']         IDC   Patient ID
# 4         DST   Identifier         ['Subject']         PDC      case_id
#
#   ent_2_extra_handles
# 0            ['case']
# 1            ['case']
# 2            ['case']
# 3            ['file']
# 4            ['case']

# %% [markdown]
# ##### Filter for only C2M2 model

# %%
c2m2_mapping_df = dss_mapping_df[dss_mapping_df["ent_2_model"] == "C2M2"]

# %%
c2m2_mapping_df.reset_index(inplace=True, drop=True)

# %%
c2m2_mapping_df.shape
# Out:
# (19, 6)

# %%
c2m2_mapping_df.head()
# Out:
#   ent_1_model ent_1_handle ent_1_extra_handles ent_2_model ent_2_handle  \
# 0         DST   Identifier         ['Subject']        C2M2     local_id
# 1         DST         Type        ['Specimen']        C2M2   assay_type
# 2         DST    Ethnicity         ['Subject']        C2M2    ethnicity
# 3         DST         Race         ['Subject']        C2M2         race
# 4         DST       Format            ['File']        C2M2           id
#
#   ent_2_extra_handles
# 0       ['biosample']
# 1       ['biosample']
# 2         ['subject']
# 3    ['subject_race']
# 4     ['file_format']

# %% [markdown]
# ##### Check original mapping spreadsheet and add any missing ents/mappings

# %%
c2m2_mapping_df
# Out:
#    ent_1_model                ent_1_handle ent_1_extra_handles ent_2_model  \
# 0          DST                  Identifier         ['Subject']        C2M2
# 1          DST                        Type        ['Specimen']        C2M2
# 2          DST                   Ethnicity         ['Subject']        C2M2
# 3          DST                        Race         ['Subject']        C2M2
# 4          DST                      Format            ['File']        C2M2
# 5          DST                  Identifier            ['File']        C2M2
# 6          DST                        Name         ['Program']        C2M2
# 7          DST                       Taxon         ['Subject']        C2M2
# 8          DST                        Type            ['File']        C2M2
# 9          DST                        Name           ['Study']        C2M2
# 10         DST           Investigator Name       ['Principal']        C2M2
# 11         DST               Anatomic Site        ['Specimen']        C2M2
# 12         DST                  Identifier           ['Study']        C2M2
# 13         DST       Sex (Genotypic Sex)\n         ['Subject']        C2M2
# 14         DST                      symbol            ['Gene']        C2M2
# 15         DST                  Identifier         ['Project']        C2M2
# 16         DST                        Code         ['Disease']        C2M2
# 17         DST                    Modality         ['Imaging']        C2M2
# 18         DST  age at specimen collection         ['Subject']        C2M2
#
#        ent_2_handle         ent_2_extra_handles
# 0          local_id               ['biosample']
# 1        assay_type               ['biosample']
# 2         ethnicity                 ['subject']
# 3              race            ['subject_race']
# 4                id             ['file_format']
# 5          local_id                    ['file']
# 6              name                 ['project']
# 7       taxonomy_id   ['subject_role_taxonomy']
# 8         data_type                    ['file']
# 9              name                 ['project']
# 10     contact_name                     ['dcc']
# 11          anatomy               ['biosample']
# 12         local_id                 ['project']
# 13              sex                 ['subject']
# 14               id                    ['gene']
# 15         local_id                 ['project']
# 16               id                 ['disease']
# 17        mime_type                    ['file']
# 18  age_at_sampling  ['biosample_from_subject']

# %%
# additional lines to add (mapped in comments but not explicitly mapped in spreadsheet)
ent_1_model = ["DST", "DST", "DST"]
ent_1_handle = ["Type", "symbol", "Identifier"]
ent_1_extra_handles = ["File", "Gene", "Project"]
ent_2_model = ["C2M2", "C2M2", "C2M2"]
ent_2_handle = ["mime_type", "name", "local_id"]
ent_2_extra_handles = ["file", "gene", "collection"]

extra_dict = {
    "ent_1_model": ent_1_model,
    "ent_1_handle": ent_1_handle,
    "ent_1_extra_handles": ent_1_extra_handles,
    "ent_2_model": ent_2_model,
    "ent_2_handle": ent_2_handle,
    "ent_2_extra_handles": ent_2_extra_handles
}

c2m2_extra = pd.DataFrame(extra_dict)

c2m2_extra.head()
# Out:
#   ent_1_model ent_1_handle ent_1_extra_handles ent_2_model ent_2_handle  \
# 0         DST         Type                File        C2M2    mime_type
# 1         DST       symbol                Gene        C2M2         name
# 2         DST   Identifier             Project        C2M2     local_id
#
#   ent_2_extra_handles
# 0                file
# 1                gene
# 2          collection

# %%
c2m2_extra["ent_1_extra_handles"] = [[l] for l in c2m2_extra["ent_1_extra_handles"]] # listify extra handles
c2m2_extra["ent_2_extra_handles"] = [[l] for l in c2m2_extra["ent_2_extra_handles"]] # listify extra handles

# %%
c2m2_extra
# Out:
#   ent_1_model ent_1_handle ent_1_extra_handles ent_2_model ent_2_handle  \
# 0         DST         Type              [File]        C2M2    mime_type
# 1         DST       symbol              [Gene]        C2M2         name
# 2         DST   Identifier           [Project]        C2M2     local_id
#
#   ent_2_extra_handles
# 0              [file]
# 1              [gene]
# 2        [collection]

# %%
c2m2_mapping_df_all = c2m2_mapping_df.append(c2m2_extra, ignore_index=True) # ignore index?

# %%
len(c2m2_mapping_df_all)
# Out:
# 22

# %%
c2m2_mapping_df_all
# Out:
#    ent_1_model                ent_1_handle ent_1_extra_handles ent_2_model  \
# 0          DST                  Identifier         ['Subject']        C2M2
# 1          DST                        Type        ['Specimen']        C2M2
# 2          DST                   Ethnicity         ['Subject']        C2M2
# 3          DST                        Race         ['Subject']        C2M2
# 4          DST                      Format            ['File']        C2M2
# 5          DST                  Identifier            ['File']        C2M2
# 6          DST                        Name         ['Program']        C2M2
# 7          DST                       Taxon         ['Subject']        C2M2
# 8          DST                        Type            ['File']        C2M2
# 9          DST                        Name           ['Study']        C2M2
# 10         DST           Investigator Name       ['Principal']        C2M2
# 11         DST               Anatomic Site        ['Specimen']        C2M2
# 12         DST                  Identifier           ['Study']        C2M2
# 13         DST       Sex (Genotypic Sex)\n         ['Subject']        C2M2
# 14         DST                      symbol            ['Gene']        C2M2
# 15         DST                  Identifier         ['Project']        C2M2
# 16         DST                        Code         ['Disease']        C2M2
# 17         DST                    Modality         ['Imaging']        C2M2
# 18         DST  age at specimen collection         ['Subject']        C2M2
# 19         DST                        Type              [File]        C2M2
# 20         DST                      symbol              [Gene]        C2M2
# 21         DST                  Identifier           [Project]        C2M2
#
#        ent_2_handle         ent_2_extra_handles
# 0          local_id               ['biosample']
# 1        assay_type               ['biosample']
# 2         ethnicity                 ['subject']
# 3              race            ['subject_race']
# 4                id             ['file_format']
# 5          local_id                    ['file']
# 6              name                 ['project']
# 7       taxonomy_id   ['subject_role_taxonomy']
# 8         data_type                    ['file']
# 9              name                 ['project']
# 10     contact_name                     ['dcc']
# 11          anatomy               ['biosample']
# 12         local_id                 ['project']
# 13              sex                 ['subject']
# 14               id                    ['gene']
# 15         local_id                 ['project']
# 16               id                 ['disease']
# 17        mime_type                    ['file']
# 18  age_at_sampling  ['biosample_from_subject']
# 19        mime_type                      [file]
# 20             name                      [gene]
# 21         local_id                [collection]

# %% [markdown]
# ##### Export clean csv with C2M2 mappings

# %%
c2m2_mapping_df_all.to_csv("Mappings/c2m2_dss_mappings_clean.csv", index=False)

# %% [markdown]
# ### Run script to add mappings to MDB

# %%
# !python "Script/link_synonym_ents_csv.py" --csv_filepath="Mappings/c2m2_dss_mappings_clean.csv" --mdb_uri="bolt://localhost:7687" --mdb_user="neo4j" --mdb_pass="blank1" --entity_type="property" --add_missing_ent_1="True" --add_missing_ent_2="False" --_commit="2022-11-30_c2m2-dss-map"
# Out:
# Creating new property node with properties: {handle: 'Identifier', model: 'DST', nanoid: 'atumqd', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'atumqd', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: '6f944Q', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'atumqd', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: '6f944Q', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'local_id', model: 'C2M2', nanoid: 'ghNETS'} to dst concept with properties: {nanoid: '6f944Q', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Type', model: 'DST', nanoid: '27bP76', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Specimen', model: 'DST', nanoid: 'kw8yZB', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Specimen', model: 'DST', nanoid: 'kw8yZB', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Type', model: 'DST', nanoid: '27bP76', _commit: '2022-11-30_c2m2-dss-map'}
# One of the two entities not found in MDB, skipping linkage for now.
# Creating new property node with properties: {handle: 'Ethnicity', model: 'DST', nanoid: 'U7bwcR', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} to dst property with properties: {handle: 'Ethnicity', model: 'DST', nanoid: 'U7bwcR', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'YcBh1S', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Ethnicity', model: 'DST', nanoid: 'U7bwcR', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'YcBh1S', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'ethnicity', model: 'C2M2', nanoid: 'aS53di'} to dst concept with properties: {nanoid: 'YcBh1S', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Race', model: 'DST', nanoid: '3t0uqu', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} to dst property with properties: {handle: 'Race', model: 'DST', nanoid: '3t0uqu', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'eX912z', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Race', model: 'DST', nanoid: '3t0uqu', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'eX912z', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'race', model: 'C2M2', nanoid: 'Qrsf7S'} to dst concept with properties: {nanoid: 'eX912z', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Format', model: 'DST', nanoid: 'gdUzDM', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Format', model: 'DST', nanoid: 'gdUzDM', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: '7qYBga', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Format', model: 'DST', nanoid: 'gdUzDM', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: '7qYBga', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'id', model: 'C2M2', nanoid: 'DbmS3J'} to dst concept with properties: {nanoid: '7qYBga', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Identifier', model: 'DST', nanoid: 'sGGJgN', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB'} to dst property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'sGGJgN', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'RK6tth', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'sGGJgN', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'RK6tth', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'local_id', model: 'C2M2', nanoid: 'sBquyb'} to dst concept with properties: {nanoid: 'RK6tth', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Name', model: 'DST', nanoid: 'ZQbf8x', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Program', model: 'DST', nanoid: 'oMwkjS', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Program', model: 'DST', nanoid: 'oMwkjS', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Name', model: 'DST', nanoid: 'ZQbf8x', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: '2figiv', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Name', model: 'DST', nanoid: 'ZQbf8x', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: '2figiv', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'name', model: 'C2M2', nanoid: 'yi2WP1'} to dst concept with properties: {nanoid: '2figiv', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Taxon', model: 'DST', nanoid: 'RuYx54', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} to dst property with properties: {handle: 'Taxon', model: 'DST', nanoid: 'RuYx54', _commit: '2022-11-30_c2m2-dss-map'}
# One of the two entities not found in MDB, skipping linkage for now.
# Creating new property node with properties: {handle: 'Type', model: 'DST', nanoid: 'h5dwJF', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB'} to dst property with properties: {handle: 'Type', model: 'DST', nanoid: 'h5dwJF', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'i0x7E8', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Type', model: 'DST', nanoid: 'h5dwJF', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'i0x7E8', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'data_type', model: 'C2M2', nanoid: 'RbkPy9'} to dst concept with properties: {nanoid: 'i0x7E8', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Name', model: 'DST', nanoid: 'xNn4tz', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Study', model: 'DST', nanoid: 'i290aa', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Study', model: 'DST', nanoid: 'i290aa', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Name', model: 'DST', nanoid: 'xNn4tz', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Name', model: 'DST', nanoid: 'xNn4tz', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: '2figiv'}
# has_concept relationship already exists between src property with properties: {handle: 'name', model: 'C2M2', nanoid: 'yi2WP1'} to dst concept with properties: {nanoid: '2figiv'}
# Creating new property node with properties: {handle: 'Investigator Name', model: 'DST', nanoid: 'QZ1JXW', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Principal', model: 'DST', nanoid: 'a1VUar', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Principal', model: 'DST', nanoid: 'a1VUar', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Investigator Name', model: 'DST', nanoid: 'QZ1JXW', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'nPqeU6', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Investigator Name', model: 'DST', nanoid: 'QZ1JXW', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'nPqeU6', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'contact_name', model: 'C2M2', nanoid: '6GbXuT'} to dst concept with properties: {nanoid: 'nPqeU6', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Anatomic Site', model: 'DST', nanoid: 'w51AsC', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'Specimen', model: 'DST', nanoid: 'kw8yZB'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'Specimen', model: 'DST', nanoid: 'kw8yZB'} to dst property with properties: {handle: 'Anatomic Site', model: 'DST', nanoid: 'w51AsC', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'eEJ5rv', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Anatomic Site', model: 'DST', nanoid: 'w51AsC', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'eEJ5rv', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'anatomy', model: 'C2M2', nanoid: 'byu0ex'} to dst concept with properties: {nanoid: 'eEJ5rv', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xotE4X', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'Study', model: 'DST', nanoid: 'i290aa'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'Study', model: 'DST', nanoid: 'i290aa'} to dst property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xotE4X', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'BBf9wC', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xotE4X', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'BBf9wC', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'local_id', model: 'C2M2', nanoid: 'HyBKbw'} to dst concept with properties: {nanoid: 'BBf9wC', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Sex (Genotypic Sex)
# ', model: 'DST', nanoid: 'CfHTGb', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} to dst property with properties: {handle: 'Sex (Genotypic Sex)
# ', model: 'DST', nanoid: 'CfHTGb', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: '1m6jN1', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Sex (Genotypic Sex)
# ', model: 'DST', nanoid: 'CfHTGb', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: '1m6jN1', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'sex', model: 'C2M2', nanoid: 'w7QJtx'} to dst concept with properties: {nanoid: '1m6jN1', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'symbol', model: 'DST', nanoid: 'tAjqgM', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Gene', model: 'DST', nanoid: 'iyjkyr', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Gene', model: 'DST', nanoid: 'iyjkyr', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'symbol', model: 'DST', nanoid: 'tAjqgM', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'Mmfvg7', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'symbol', model: 'DST', nanoid: 'tAjqgM', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'Mmfvg7', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'id', model: 'C2M2', nanoid: 'UX3JgT'} to dst concept with properties: {nanoid: 'Mmfvg7', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xUP6Si', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Project', model: 'DST', nanoid: 'd3rmnW', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Project', model: 'DST', nanoid: 'd3rmnW', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xUP6Si', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xUP6Si', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'BBf9wC'}
# has_concept relationship already exists between src property with properties: {handle: 'local_id', model: 'C2M2', nanoid: 'HyBKbw'} to dst concept with properties: {nanoid: 'BBf9wC'}
# Creating new property node with properties: {handle: 'Code', model: 'DST', nanoid: 'Ctv1X7', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Disease', model: 'DST', nanoid: 'mgHhSC', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Disease', model: 'DST', nanoid: 'mgHhSC', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Code', model: 'DST', nanoid: 'Ctv1X7', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'xV1em7', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Code', model: 'DST', nanoid: 'Ctv1X7', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'xV1em7', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'id', model: 'C2M2', nanoid: 'JPqFBV'} to dst concept with properties: {nanoid: 'xV1em7', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'Modality', model: 'DST', nanoid: 'Nq6EBv', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new node node with properties: {handle: 'Imaging', model: 'DST', nanoid: 'Vtc5ZV', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_property relationship between src node with properties: {handle: 'Imaging', model: 'DST', nanoid: 'Vtc5ZV', _commit: '2022-11-30_c2m2-dss-map'} to dst property with properties: {handle: 'Modality', model: 'DST', nanoid: 'Nq6EBv', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new concept node with properties: {nanoid: 'iN5ejD', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'Modality', model: 'DST', nanoid: 'Nq6EBv', _commit: '2022-11-30_c2m2-dss-map'} to dst concept with properties: {nanoid: 'iN5ejD', _commit: '2022-11-30_c2m2-dss-map'}
# Adding has_concept relationship between src property with properties: {handle: 'mime_type', model: 'C2M2', nanoid: 'KjbkCB'} to dst concept with properties: {nanoid: 'iN5ejD', _commit: '2022-11-30_c2m2-dss-map'}
# Creating new property node with properties: {handle: 'age at specimen collection', model: 'DST', nanoid: 't95uUo', _commit: '2022-11-30_c2m2-dss-map'}
# Node entity with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} already exists in the database.
# Adding has_property relationship between src node with properties: {handle: 'Subject', model: 'DST', nanoid: 'UA0baG'} to dst property with properties: {handle: 'age at specimen collection', model: 'DST', nanoid: 't95uUo', _commit: '2022-11-30_c2m2-dss-map'}
# One of the two entities not found in MDB, skipping linkage for now.
# Property entity with properties: {handle: 'Type', model: 'DST', nanoid: 'h5dwJF'} already exists in the database.
# Node entity with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB'} already exists in the database.
# has_property relationship already exists between src node with properties: {handle: 'File', model: 'DST', nanoid: 'vHtztB'} to dst property with properties: {handle: 'Type', model: 'DST', nanoid: 'h5dwJF'}
# has_concept relationship already exists between src property with properties: {handle: 'Type', model: 'DST', nanoid: 'h5dwJF'} to dst concept with properties: {nanoid: 'i0x7E8'}
# Adding has_concept relationship between src property with properties: {handle: 'mime_type', model: 'C2M2', nanoid: 'KjbkCB'} to dst concept with properties: {nanoid: 'i0x7E8'}
# Property entity with properties: {handle: 'symbol', model: 'DST', nanoid: 'tAjqgM'} already exists in the database.
# Node entity with properties: {handle: 'Gene', model: 'DST', nanoid: 'iyjkyr'} already exists in the database.
# has_property relationship already exists between src node with properties: {handle: 'Gene', model: 'DST', nanoid: 'iyjkyr'} to dst property with properties: {handle: 'symbol', model: 'DST', nanoid: 'tAjqgM'}
# has_concept relationship already exists between src property with properties: {handle: 'symbol', model: 'DST', nanoid: 'tAjqgM'} to dst concept with properties: {nanoid: 'Mmfvg7'}
# Adding has_concept relationship between src property with properties: {handle: 'name', model: 'C2M2', nanoid: 'WvNcfi'} to dst concept with properties: {nanoid: 'Mmfvg7'}
# Property entity with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xUP6Si'} already exists in the database.
# Node entity with properties: {handle: 'Project', model: 'DST', nanoid: 'd3rmnW'} already exists in the database.
# has_property relationship already exists between src node with properties: {handle: 'Project', model: 'DST', nanoid: 'd3rmnW'} to dst property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xUP6Si'}
# has_concept relationship already exists between src property with properties: {handle: 'Identifier', model: 'DST', nanoid: 'xUP6Si'} to dst concept with properties: {nanoid: 'BBf9wC'}
# Adding has_concept relationship between src property with properties: {handle: 'local_id', model: 'C2M2', nanoid: 'iS5W3R'} to dst concept with properties: {nanoid: 'BBf9wC'}
